# %% [markdown]
# ## Run here metrics on NERVE performance
# see [here](https://alexlenail.medium.com/understanding-and-implementing-the-hypergeometric-test-in-python-a7db688a7458) for explanation on hypergeometric test,
# see [here](https://www.frontiersin.org/articles/10.3389/fimmu.2019.00113/full) for paper about RV software comparison

# %%
import pandas as pd
from scipy.stats import hypergeom as hg

# %%
# nerve 1 data from comparison 1 paper can be passed to the following function to obtain the p value as reported in the paper table
# hg.sf(x-1, M, n, N)
# M is the population size (previously N)
# n is the number of successes in the population (previously K)
# N is the sample size (previously n)
# X is still the number of drawn “successes”

# %%
# No razor, no mouse, no virulent
x = 11
M = 53855
n = 44
N = 813
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 0.6642280196824807
# Fold-enrichment: 16.560578105781058
# p-value: 4.230914598974088e-11

# %%
#  razor, no mouse, no virulent
x = 7
M = 53855
n = 44
N = 845
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# 5.2809944571144295e-06

# %%
#  razor,  mouse, no virulent
x = 7
M = 53855
n = 44
N = 845
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 0.6903722959799462
# Fold-enrichment: 10.139456697149004
# p-value: 5.2809944571144295e-06

# %%
#  razor,  mouse,  virulent
x = 11
M = 53855
n = 44
N = 4534
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 3.704317147897131
# Fold-enrichment: 2.9695081605646227
# p-value: 0.0008347910528206919

# %%
# Vaxign2-ML
x = 36
M = 53855
n = 44
N = 27227
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 22.24469408597159
# Fold-enrichment: 1.6183634560613294
# p-value: 1.730498133876489e-05

# %%
# Vaxign2-filtering
x = 8
M = 53855
n = 44
N = 1059
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 0.8652121437192462
# Fold-enrichment: 9.24628723495579
# p-value: 2.0606589527789008e-06

# %%
# Vaxijen
x = 31
M = 53855
n = 44
N = ...
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')

# %%
# NERVE 1 test set
x = 33
M = 27449
n = 42
N = 2181
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 3.3371707530328973
# Fold-enrichment: 9.888615969083645
# p-value: 8.853032896587171e-29

# %%
# NERVE 2 (no razor, no mouse, no) on NERVE 1 test set
x = 29
M = 27449
n = 42
N = 491
expected = (N * n ) / M
fe = x / expected
p = hg.sf(x-1, M, n, N)
print(f'Expected: {expected}')
print(f'Fold-enrichment: {fe}')
print(f'p-value: {p}')
# Out:
# Expected: 0.7512841997886991
# Fold-enrichment: 38.60057220444185
# p-value: 1.8984034339585293e-41
